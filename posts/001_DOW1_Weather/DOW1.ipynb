# %% [raw]
# ---
# title: "Dataset of the Week #1: The Weather in Philadelphia"
# author: Emilie
# date: 1/28/2026
# categories:
#   - DOW
#   - Weather
# ---

# %% [markdown]
# ### My post

# %% [markdown]
# print("This is some code")

# %% [markdown]
# ![](IMG_3721.jpeg){width=300}

# %% [markdown]
# ---
#
#
#
# The next section
#
#
#
#
# ---
#
#
#
# And another
#
#
#
#
# ---
