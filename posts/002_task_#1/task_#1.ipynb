# %% [raw]
# ---
# title: "Task #1 in experimenting with website"
# description: "How to make a new post appear"
# author: "Emilie"
# date: "1/23/2026"
# categories:
#   - LLMs
#   - Experiment
# ---

# %% [markdown]
# Let's hope this works out!
